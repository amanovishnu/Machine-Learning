# %%
import pandas as pd
import matplotlib.pyplot as plt;
import numpy as np;
import seaborn as sns;
import os;

# %%
iris = pd.read_csv("Datasets/iris.csv")
test = iris.columns
# for x in test:
#     print('Data Point/Independent Variable/Feature ->',x)
#     print(iris[x].value_counts())
# iris['species'].value_counts()
# '''There are Equal no of entries for all types of flowers hence it forms a balanced dataset'''

# %%
iris.plot(kind='scatter',x='sepal_length', y='sepal_width')
plt.show()
sns.set_style('whitegrid');
sns.FacetGrid(iris,hue="species",height=6).map(plt.scatter,"sepal_length","sepal_width").add_legend();

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris,hue='species',height=3);
plt.show();

# %%
iris_setosa = iris.loc[iris['species']=='setosa'];
iris_virginica = iris.loc[iris['species']=='virginica'];
iris_versicolor = iris.loc[iris['species']=='versicolor'];
print(iris_setosa['species'].value_counts());
print(iris_virginica['species'].value_counts());
print(iris_versicolor['species'].value_counts());
plt.plot(iris_setosa["petal_length"],np.zeros(len(iris_setosa)),'o');
plt.plot(iris_virginica["petal_length"],np.zeros(len(iris_virginica)),'o');
plt.plot(iris_versicolor["petal_length"],np.zeros(len(iris_versicolor)),'o');
# Out:
# setosa    50
# Name: species, dtype: int64
# virginica    50
# Name: species, dtype: int64
# versicolor    50
# Name: species, dtype: int64

# %%
# sns.relplot(kind='scatter', x='sepal_length',y='petal_length', data=iris, hue='species');
sales = pd.read_csv('Datasets/sales.csv');
sales.columns
sns.relplot(x='Sales',y='Profit',data=sales, hue='Order Priority', style="Ship Mode")
plt.show()

# %%
import seaborn as sns;
import pandas as pd;

# %%
sales = pd.read_csv('Datasets/sales.csv')
sns.relplot(x='Sales',y='Profit',data=sales)

# %%
sns.relplot(x='Sales',y='Profit',data=sales, hue='Order Priority')

# %%
sns.relplot(x='Sales',y='Profit',data=sales,hue='Order Priority',style='Order Priority')

# %%
sns.relplot(x='Sales',y='Profit',data=sales,hue='Order Priority', style='Ship Mode')

# %%
sns.relplot(x="Sales",y="Profit",data=sales,hue="Order Priority", style="Ship Mode",size='Unit Price')
plt.show()
# sales['Discount'].value_counts()

# %%
sns.relplot(x='Sales' ,y='Profit', data=sales, hue='Order Priority', style='Ship Mode', size='Discount', sizes=(25,200))
